# %% [markdown]
# Basically, I'm going to try and create a unified CSV file from the taxi fare data and the weather data in this file

# %%
import pandas as pd

# %%
weather = pd.read_csv('centralParkWeather.csv')

# %%
taxi_sample = pd.read_csv('reduced.csv')
taxi_sample.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# ...

# %% [markdown]
# Note, AWND is average daily wind speed AWND = Average daily wind speed (tenths of meters per second)
#
#
#     PRCP = Precipitation (tenths of mm)
#     SNOW = Snowfall (mm)
#     SNWD = Snow depth (mm)
#     TMAX = Maximum temperature (tenths of degrees C)
#     TMIN = Minimum temperature (tenths of degrees C)

# %% [markdown]
# So, try joining on a column with a subset of the data

# %%
taxi_sample.loc[0][0]
# Out:
# '2009-06-15 17:26:21.0000001'

# %% [markdown]
# create a column that converts the key datetime stamp to a date so that it can be joined with the weather data

# %%
def date(timestamp):
    return timestamp.split()[0]

taxi_sample['DATE'] = taxi_sample.apply(lambda x: date(x['key']), axis=1)

# %%
taxi_sample.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count        DATE
# 0                1  2009-06-15
# ...

# %%
df_join = pd.merge(taxi_sample, weather, how='left', on='DATE')

# %%
df_join.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count        DATE      STATION                         NAME  \
# ...

# %%
len(df_join)
# Out:
# 50000

# %%
len(taxi_sample)
# Out:
# 50000

# %%
df_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key                50000 non-null  object
#  1   fare_amount        50000 non-null  float64
#  2   pickup_datetime    50000 non-null  object
#  3   pickup_longitude   50000 non-null  float64
#  4   pickup_latitude    50000 non-null  float64
#  5   dropoff_longitude  50000 non-null  float64
#  6   dropoff_latitude   50000 non-null  float64
#  7   passenger_count    50000 non-null  int64
#  8   DATE               50000 non-null  object
#  9   STATION            50000 non-null  object
#  10  NAME               50000 non-null  object
#  11  AWND               49539 non-null  float64
#  12  PRCP               50000 non-null  float64
#  13  SNOW               50000 non-null  float64
#  14  SNWD               50000 non-null  int64
#  15  TMAX               50000 non-null  int64
# ...

# %%
df_join.loc[40900]
# Out:
# key                  2015-03-19 13:38:57.0000005
# fare_amount                                   25
# pickup_datetime          2015-03-19 13:38:57 UTC
# pickup_longitude                        -73.9819
# pickup_latitude                           40.767
# dropoff_longitude                       -74.0025
# dropoff_latitude                         40.7157
# passenger_count                                1
# DATE                                  2015-03-19
# STATION                              USW00094728
# NAME                 NY CITY CENTRAL PARK, NY US
# AWND                                        5.82
# PRCP                                           0
# SNOW                                           0
# SNWD                                           0
# TMAX                                          43
# TMIN                                          29
# Name: 40900, dtype: object

# %% [markdown]
# drop the irrelevant columns

# %%
taxi_sample
# Out:
#                                  key  fare_amount          pickup_datetime  \
# 0        2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1        2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2       2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3        2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4      2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                              ...          ...                      ...
# 49995    2013-06-12 23:25:15.0000004         15.0  2013-06-12 23:25:15 UTC
# 49996    2015-06-22 17:19:18.0000007          7.5  2015-06-22 17:19:18 UTC
# 49997   2011-01-30 04:53:00.00000063          6.9  2011-01-30 04:53:00 UTC
# 49998   2012-11-06 07:09:00.00000069          4.5  2012-11-06 07:09:00 UTC
# 49999    2010-01-13 08:13:14.0000007         10.9  2010-01-13 08:13:14 UTC
#
# ...

# %%
weather.loc[369]
# Out:
# STATION                    USW00094728
# NAME       NY CITY CENTRAL PARK, NY US
# DATE                        2010-01-05
# AWND                              9.84
# PRCP                                 0
# SNOW                                 0
# SNWD                                 0
# TMAX                                30
# TMIN                                20
# Name: 369, dtype: object

# %%
df_join.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count        DATE      STATION                         NAME  \
# ...

# %%
from datetime import datetime

date = '2009-01-05'

df = '1'

# 0 - Monday, 1 - Tuesday, etc. 

def day_of_week(date):
    return datetime.strptime(date, '%Y-%m-%d').weekday()

df[''] = df.apply(lambda x: day_of_week(x['pickup_datetime']), axis=1)

print(day_of_week(date))
